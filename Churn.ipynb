# %%
import pandas as pd

file_path = '/Users/artimesrashiditorghi/Desktop/Churn.csv'

df = pd.read_csv(file_path)

df.head()
# Out:
#    customerID  gender  SeniorCitizen Partner Dependents  tenure PhoneService  \
# 0  7590-VHVEG  Female              0     Yes         No       1           No
# 1  5575-GNVDE    Male              0      No         No      34          Yes
# 2  3668-QPYBK    Male              0      No         No       2          Yes
# 3  7795-CFOCW    Male              0      No         No      45           No
# 4  9237-HQITU  Female              0      No         No       2          Yes
#
#       MultipleLines InternetService OnlineSecurity  ... DeviceProtection  \
# 0  No phone service             DSL             No  ...               No
# 1                No             DSL            Yes  ...              Yes
# 2                No             DSL            Yes  ...               No
# 3  No phone service             DSL            Yes  ...              Yes
# 4                No     Fiber optic             No  ...               No
#
# ...

# %%
summary_statistics = df.describe()

summary_statistics
# Out:
#        SeniorCitizen       tenure  MonthlyCharges
# count    7043.000000  7043.000000     7043.000000
# mean        0.162147    32.371149       64.761692
# std         0.368612    24.559481       30.090047
# min         0.000000     0.000000       18.250000
# 25%         0.000000     9.000000       35.500000
# 50%         0.000000    29.000000       70.350000
# 75%         0.000000    55.000000       89.850000
# max         1.000000    72.000000      118.750000

# %%
summary_statistics_all = df.describe(include='all')


summary_statistics_all
# Out:
#         customerID gender  SeniorCitizen Partner Dependents       tenure  \
# count         7043   7043    7043.000000    7043       7043  7043.000000
# unique        7043      2            NaN       2          2          NaN
# top     7590-VHVEG   Male            NaN      No         No          NaN
# freq             1   3555            NaN    3641       4933          NaN
# mean           NaN    NaN       0.162147     NaN        NaN    32.371149
# std            NaN    NaN       0.368612     NaN        NaN    24.559481
# min            NaN    NaN       0.000000     NaN        NaN     0.000000
# 25%            NaN    NaN       0.000000     NaN        NaN     9.000000
# 50%            NaN    NaN       0.000000     NaN        NaN    29.000000
# 75%            NaN    NaN       0.000000     NaN        NaN    55.000000
# max            NaN    NaN       1.000000     NaN        NaN    72.000000
#
#        PhoneService MultipleLines InternetService OnlineSecurity  ...  \
# ...

# %%
summary_statistics_all.to_csv('/Users/artimesrashiditorghi/Desktop/summary_statistics_all.csv', index=False)

# %%
import matplotlib.pyplot as plt
import seaborn as sns


sns.set(style="whitegrid")

# %%
# Visualization 1: Senior Citizens Percentage
plt.figure(figsize=(8, 5))
sns.countplot(x='SeniorCitizen', data=df, palette='viridis')
plt.title('Distribution of Senior Citizens')
plt.xlabel('Senior Citizen (0: No, 1: Yes)')
plt.ylabel('Count')
plt.show()

# %%
# Visualization 2: Phone Service and Multiple Lines
plt.figure(figsize=(12, 5))
sns.countplot(x='PhoneService', hue='MultipleLines', data=df, palette='muted')
plt.title('Phone Service and Multiple Lines Distribution')
plt.xlabel('Phone Service')
plt.ylabel('Count')
plt.legend(title='Multiple Lines', loc='upper right')
plt.show()

# %%
# Visualization 3: Internet Service Distribution
plt.figure(figsize=(8, 5))
sns.countplot(x='InternetService', data=df, palette='Set2')
plt.title('Distribution of Internet Service')
plt.xlabel('Internet Service Type')
plt.ylabel('Count')
plt.show()

# %%
# Visualization 4: Contract and Paperless Billing
plt.figure(figsize=(12, 5))
sns.countplot(x='Contract', hue='PaperlessBilling', data=df, palette='pastel')
plt.title('Contract and Paperless Billing Distribution')
plt.xlabel('Contract Type')
plt.ylabel('Count')
plt.legend(title='Paperless Billing', loc='upper right')
plt.show()

# %%
# Visualization 5: Churn vs Monthly Charges
plt.figure(figsize=(10, 6))
sns.boxplot(x='Churn', y='MonthlyCharges', data=df, palette='pastel')
plt.title('Churn vs Monthly Charges')
plt.xlabel('Churn (0: No, 1: Yes)')
plt.ylabel('Monthly Charges')
plt.show()

# %%
# Visualization 6: Contract Type vs Monthly Charges
plt.figure(figsize=(12, 6))
sns.boxplot(x='Contract', y='MonthlyCharges', data=df, palette='Set2')
plt.title('Contract Type vs Monthly Charges')
plt.xlabel('Contract Type')
plt.ylabel('Monthly Charges')
plt.show()

# %%
# Visualization7: Churn vs Contract
plt.figure(figsize=(10, 6))
sns.countplot(x='Contract', hue='Churn', data=df, palette='pastel')
plt.title('Churn vs Contract Distribution')
plt.xlabel('Contract Type')
plt.ylabel('Count')
plt.legend(title='Churn (0: No, 1: Yes)', loc='upper right')
plt.show()

# %%
import pandas as pd
from scipy.stats import chi2_contingency


contingency_table = pd.crosstab(df['Contract'], df['Churn'])


chi2, p, _, _ = chi2_contingency(contingency_table)

print(f"Chi-squared value: {chi2}")
print(f"P-value: {p}")


if p < 0.05:
    print("Reject the null hypothesis. There is a significant association between Contract type and Churn.")
else:
    print("Fail to reject the null hypothesis. There is no significant association between Contract type and Churn.")
# Out:
# Chi-squared value: 1184.5965720837926
# P-value: 5.863038300673391e-258
# Reject the null hypothesis. There is a significant association between Contract type and Churn.

# %%
import pandas as pd
from scipy.stats import chi2_contingency


contingency_table_internet = pd.crosstab(df['InternetService'], df['Churn'])

chi2_internet, p_internet, _, _ = chi2_contingency(contingency_table_internet)


print(f"Chi-squared value for Internet Service: {chi2_internet}")
print(f"P-value for Internet Service: {p_internet}")


if p_internet < 0.05:
    print("Reject the null hypothesis. There is a significant association between Internet Service type and Churn.")
else:
    print("Fail to reject the null hypothesis. There is no significant association between Internet Service type and Churn.")
# Out:
# Chi-squared value for Internet Service: 732.309589667794
# P-value for Internet Service: 9.571788222840544e-160
# Reject the null hypothesis. There is a significant association between Internet Service type and Churn.

# %%
from scipy.stats import ttest_ind

churned = df[df['Churn'] == 'Yes']['MonthlyCharges']
not_churned = df[df['Churn'] == 'No']['MonthlyCharges']

# independent two-sample t-test
t_stat, p_value = ttest_ind(churned, not_churned, equal_var=False)


print(f"T-statistic: {t_stat}")
print(f"P-value: {p_value}")


if p_value < 0.05:
    print("Reject the null hypothesis. There is a significant difference in mean monthly charges between churned and not-churned customers.")
else:
    print("Fail to reject the null hypothesis. There is no significant difference in mean monthly charges between churned and not-churned customers.")
# Out:
# T-statistic: 18.407526676414673
# P-value: 8.592449331547539e-73
# Reject the null hypothesis. There is a significant difference in mean monthly charges between churned and not-churned customers.

# %%
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LogisticRegression
from sklearn.preprocessing import StandardScaler
from sklearn.metrics import accuracy_score, classification_report, confusion_matrix


# Standardize numerical variables
scaler = StandardScaler()
X_scaled = scaler.fit_transform(X)

# Split 
X_train, X_test, y_train, y_test = train_test_split(X_scaled, y, test_size=0.2, random_state=42)


logreg_model = LogisticRegression(max_iter=1000, solver='liblinear')


logreg_model.fit(X_train, y_train)

# Make predictions on the test
y_pred = logreg_model.predict(X_test)

# Evaluate 
accuracy = accuracy_score(y_test, y_pred)
conf_matrix = confusion_matrix(y_test, y_pred)
class_report = classification_report(y_test, y_pred)

# Print the results
print(f"Accuracy: {accuracy}")
print("Confusion Matrix:")
print(conf_matrix)
print("Classification Report:")
print(class_report)
# Out:
# Accuracy: 0.6997870830376153
# Confusion Matrix:
# [[685 351]
#  [ 72 301]]
# Classification Report:
#               precision    recall  f1-score   support
#
#           No       0.90      0.66      0.76      1036
#          Yes       0.46      0.81      0.59       373
#
#     accuracy                           0.70      1409
#    macro avg       0.68      0.73      0.68      1409
# weighted avg       0.79      0.70      0.72      1409

# %%
 import pandas as pd
import numpy as np
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LogisticRegression
from sklearn.preprocessing import StandardScaler


X = df.drop(['customerID', 'Churn'], axis=1)


X = pd.get_dummies(X, drop_first=True)

scaler = StandardScaler()
X_scaled = scaler.fit_transform(X)


y = df['Churn']

X_train, X_test, y_train, y_test = train_test_split(X_scaled, y, test_size=0.2, random_state=42)


logreg_model = LogisticRegression(max_iter=1000, solver='liblinear')


logreg_model.fit(X_train, y_train)


coefficients = logreg_model.coef_[0]

odds_ratios = np.exp(coefficients)


odds_ratio_df = pd.DataFrame({'Feature': X.columns, 'Coefficient': coefficients, 'Odds Ratio': odds_ratios})


sorted_odds_ratio_df = odds_ratio_df.sort_values(by='Odds Ratio', ascending=False)


print(sorted_odds_ratio_df)
# Out:
#                            Feature  Coefficient  Odds Ratio
# 9      InternetService_Fiber optic     1.118707    3.060894
# 22             StreamingMovies_Yes     1.058068    2.880799
# 27  PaymentMethod_Electronic check     0.741835    2.099785
# 28      PaymentMethod_Mailed check     0.539176    1.714593
# 2                   MonthlyCharges     0.469601    1.599356
# ..                             ...          ...         ...
# 18                 TechSupport_Yes    -0.462264    0.629856
# 24               Contract_Two year    -0.476291    0.621082
# 14                OnlineBackup_Yes    -0.779919    0.458443
# 1                           tenure    -1.016655    0.361803
# 16            DeviceProtection_Yes    -1.156709    0.314520
#
# [6559 rows x 3 columns]

# %%
# Out:
#                           Feature  Coefficient  Abs_Coefficient
# 16           DeviceProtection_Yes    -1.156709         1.156709
# 9     InternetService_Fiber optic     1.118707         1.118707
# 22            StreamingMovies_Yes     1.058068         1.058068
# 1                          tenure    -1.016655         1.016655
# 14               OnlineBackup_Yes    -0.779919         0.779919
# ...                           ...          ...              ...
# 4971          TotalCharges_6046.1    -0.000075         0.000075
# 200          TotalCharges_1088.25     0.000056         0.000056
# 52              TotalCharges_1010     0.000037         0.000037
# 5312          TotalCharges_6637.9    -0.000021         0.000021
# 5222          TotalCharges_6468.6     0.000007         0.000007
#
# [6559 rows x 3 columns]
